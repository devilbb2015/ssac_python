# %% [markdown]
# # 인스타그램 크롤링하여 이미지 다운로드 하기

# %%
# 1) Import되는 라이브러리들을 설치되어 있어야 한다.

# 2) chromedriver를 구글에서 다운받아 파이썬파일이 저장된 폴더에 넣어 놓아야 한다.
#   - 사용중인 크롬 브라우저 검색창에 chrome://settings/ 을 입력하여 버전을 확인
#   - https://chromedriver.chromium.org/home
#   - driver = webdriver.Chrome() 파일 경로 설정
#  주의) 오류시 버전오류가 발생일 가능성 높음 => chrome버전과 일치되는 chrome driver버전을 다운받아서 해당 파일 위치를 설정 필요

# %%
# 대다수 인터넷에 있는 코드들이 처음 화면에 뜨는 33개 까지만 다운받을 수 있음

# %%
#[Code 1]
# 라이브러리 설치 및 불러오기 
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import requests
import shutil

# 이미지를 불러올 검색결과 페이지 변수 셋팅 
baseUrl = 'https://www.instagram.com/explore/tags/'
plusUrl = input('검색할 태그를 입력하세요:')
url = baseUrl + quote_plus(plusUrl)

# 크롬 드라이버 실행
driver = webdriver.Chrome()
driver.get(url)

# 3초간 쉬라는 의미 - 몇 초간 쉬는 것이 좋은지는 서버 상황에 따라 상이하나, 3초 정도 쉬어주면 서버에 크게 무리 주지 않고 접근 가능
time.sleep(3)

html = driver.page_source
soup = BeautifulSoup(html)

# 인스타그램의 검색결과 페이지 중 첫번째 이미지의 태그 (오늘날짜로 확인)
insta = soup.select('.v1Nh3.kIKUG._bz0w')  #클래스간에 공백없이 .으로 불러오기 

# select를 통해 <img src=> 에 해당하는 주소를 읽고 디렉토리에 저장
n = 1
for i in insta :       
        print('https://www.instagram.com'+i.a['href'])
        imgUrl = i.select_one('.KL4Bh').img['src'] # 첫번째 사진의 테크
        with urlopen(imgUrl) as f:
            with open('./img/'+ plusUrl + str(n) + '.jpg', 'wb') as h:
                img = f.read()
                h.write(img)
        n += 1
        print(imgUrl)
        print()
        

driver.close()
# Out:
# 검색할 태그를 입력하세요:차차차
# https://www.instagram.com/p/CN3rOW8Fin6/
# https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c0.180.1440.1440a/s640x640/174953774_809992632963107_3123568489762356722_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=111&_nc_ohc=4W1U0mbAEIcAX9SwRGB&edm=ABZsPhsBAAAA&ccb=7-4&oh=9927e550796df65bf6a4a4eaf44c8622&oe=6182065A&_nc_sid=4efc9f
#
# https://www.instagram.com/p/CPC0-gfluw2/
# https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c179.0.1081.1081a/s640x640/187323773_481027419667493_3964065675469970396_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=105&_nc_ohc=92H1AJh9mBYAX-0pB0-&edm=ABZsPhsBAAAA&ccb=7-4&oh=38ced084c1e4686ca19fa5ec4e097640&oe=61808D40&_nc_sid=4efc9f
#
# https://www.instagram.com/p/CFgcKgFFKYJ/
# https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c276.0.888.888a/s640x640/119981407_367433347761323_9105893953068392483_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=111&_nc_ohc=gV29yQxKdYYAX8lJRVM&edm=ABZsPhsBAAAA&ccb=7-4&oh=d5252a02675cf487275aca8ce0b99eeb&oe=6180CB5C&_nc_sid=4efc9f
#
# https://www.instagram.com/p/CTrS8gWlKkO/
# https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/s640x640/241565136_819585045385403_5318251403541403437_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=111&_nc_ohc=WB0wKxRZ_AgAX-lN8Uv&edm=ABZsPhsBAAAA&ccb=7-4&oh=5cc838630f6c274779b85bed9eb15ecb&oe=61809A57&_nc_sid=4efc9f
#
# https://www.instagram.com/p/CUkd0ZyFGsc/
# https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/s640x640/244040023_1336138940134621_2299197197997995771_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=SS9HOMIP3ZQAX9A2LKj&edm=ABZsPhsBAAAA&ccb=7-4&oh=fde936ad8f8d669ab56bafe71ef266d3&oe=6181EEC7&_nc_sid=4efc9f
#
# https://www.instagram.com/p/
://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/sh0.08/e35/c0.135.1080.1080a/s640x640/248394470_411853410500294_2049989928316631714_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=102&_nc_ohc=ldeoZObdTtUAX9I1RcR&edm=ABZsPhsBAAAA&ccb=7-4&oh=957d1f05f2cd0d9571c17b2149725d0f&oe=6180B262&_nc_sid=4efc9f

# %%
# 이미지 다운로드 33개의 한계를 해결하기
# 예제에서 이미지 다운로드를 확장하기 위하여 60개로 설정 
# 해결책) 이미지 다운로드를 더 늘리고 싶다면 반복횟수를 바꾸고 이미지저장 횟수를 늘려주면 가능

# 1) for i in range(0, 5): 이 코드에서 5는 스크롤 내리는 반복횟수라 변경하면 됨
# 2) for i in range(0, 60): 이 코드에서 60은 읽어온 이미지를 저장하는 행위를 반복하는 횟수라 변경하면 됨

# %%
#[Code 2]
# 라이브러리 설치 및 불러오기 
from urllib.request import urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import requests
import shutil

# 이미지를 불러올 검색결과 페이지 변수 셋팅 
baseUrl = 'https://www.instagram.com/explore/tags/'
plusUrl = input('검색할 태그를 입력하세요 : ')
url = baseUrl + quote_plus(plusUrl)

driver = webdriver.Chrome()
driver.get(url)

time.sleep(3)

html = driver.page_source
soup = BeautifulSoup(html)

imglist = []


for i in range(0, 5):

    insta = soup.select('.v1Nh3.kIKUG._bz0w')

    for i in insta:

        print('https://www.instagram.com'+ i.a['href'])
        imgUrl = i.select_one('.KL4Bh').img['src']
        imglist.append(imgUrl)
        imglist = list(set(imglist))
        html = driver.page_source
        soup = BeautifulSoup(html)
        insta = soup.select('.v1Nh3.kIKUG._bz0w')
        
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)

n=0

for i in range(0, 60):
    # This is the image url.
    image_url = imglist[n]
    # Open the url image, set stream to True, this will return the stream content.
    resp = requests.get(image_url, stream=True)
    # Open a local file with wb ( write binary ) permission.
    local_file = open('./img/' + plusUrl + str(n) + '.jpg', 'wb')
    # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
    resp.raw.decode_content = True
    # Copy the response stream raw data to local image file.
    shutil.copyfileobj(resp.raw, local_file)
    # Remove the image url response object.
    n +=1
    del resp

driver.close()

# print(imgUrl)
# print(imglist)
# Out:
# 검색할 태그를 입력하세요 : 라이언
# https://www.instagram.com/p/CVc17ArJwjO/
# https://www.instagram.com/p/CVedVyYplZ8/
# https://www.instagram.com/p/CVJ6h0KJL-2/
# https://www.instagram.com/p/CUq25E1pWdW/
# https://www.instagram.com/p/CVOfUGEhYWB/
# https://www.instagram.com/p/CVExkV_J2B1/
# https://www.instagram.com/p/CVCFrecJgIb/
# https://www.instagram.com/p/CVUqrTlJssL/
# https://www.instagram.com/p/CVeIc7chS1i/
# https://www.instagram.com/p/CVkN2RMPOdm/
# https://www.instagram.com/p/CVkMX47BQw_/
# https://www.instagram.com/p/CVkKF0Lv5wo/
# https://www.instagram.com/p/CVkEuQoPD6o/
# https://www.instagram.com/p/CVkEtBvJrSY/
# https://www.instagram.com/p/CVkDlyDpRpe/
# https://www.instagram.com/p/CVkC7OfBOYO/
# https://www.instagram.com/p/CVkCYxrpEta/
# https://www.instagram.com/p/CVkAiRopKYf/
# https://www.instagram.com/p/CVkAJEtlIft/
# https://www.instagram.com/p/CVkAEfBvuHY/
# https://www.instagram.com/p/CVj_sF0pK1P/
# https://www.instagram.com/p/CVj_jw_J8PA/
# https://www.instagram.com/p/CVj_dvLpeaq/
# https://www.instagram.com/p/CVj-4lZpZXI/
# https://www.instagram.com/p/CVj98u0PudE/
# https://www.instagram.com/p/CVj8RwtJ1yO/
# https://www.instagram.com/p/CVj8Jybpp2D/
# https://www.instagram.com/p/CVj62uFhdB0/
# https://www.instagram.com/p/CVj12EMFds8/
# https://www.instagram.com/p/CVjz4j7h7BG/
# https://www.instagram.com/p/CVjyEnoJb9x/
# https://www.instagram.com/p/CVjx-UOJr9r/
# https://www.instagram.com/p/CVjxkEWhez0/
# https://www.instagram.com/p/CVc17ArJwjO/
# https://www.instagram.com/p/CVedVyYplZ8/
# https://www.instagram.com/p/CVJ6h0KJL-2/
# https://www.instagram.com/p/CUq25E1pWdW/
# https://www.instagram.com/p/CVOfUGEhYWB/
# https://www.instagram.com/p/CVExkV_J2B1/
# https://www.instagram.com/p/CVCFrecJgIb/
# https://www.instagram.com/p/CVUqrTlJssL/
# https://www.instagram.com/p/CVeIc7chS1i/
# https://www.instagram.com/p/CVkN2RMPOdm/
# https://www.instagram.com/p/CVkMX47BQw_/
# https://www.instagram.com/p/CVkKF0Lv5wo/
# https://www.instagram.com/p/CVkEuQoPD6o/
# https://www.instagram.com/p/CVkEtBvJrSY/
# https://www.instagram.com/p/CVkDlyDpRpe/
# https://www.instagram.com/p/CVkC7OfBOYO/
# https://www.instagram.com/p/CVkCYxrpEta/
# https://www.instagram.com/p/CVkAiRopKYf/
# https://www.instagram.com/p/CVkAJEtlIft/
# https://www.instagram.com/p/CVkAEfBvuHY/
# https://www.instagram.com/p/CVj_sF0pK1P/
# https://www.instagram.com/p/CVj_jw_J8PA/
# https://www.instagram.com/p/CVj_dvLpeaq/
# https://www.instagram.com/p/CVj-4lZpZXI/
# https://www.instagram.com/p/CVj98u0PudE/
# https://www.instagram.com/p/CVj8RwtJ1yO/
# https://www.instagram.com/p/CVj8Jybpp2D/
# https://www.instagram.com/p/CVj62uFhdB0/
# https://www.instagram.com/p/CVj12EMFds8/
# https://www.instagram.com/p/CVjz4j7h7BG/
# https://www.instagram.com/p/CVjyEnoJb9x/
# https://www.instagram.com/p/CVjx-UOJr9r/
# https://www.instagram.com/p/CVjxkEWhez0/
# https://www.instagram.com/p/CVc17ArJwjO/
# https://www.instagram.com/p/CVedVyYplZ8/
# https://www.instagram.com/p/CVJ6h0KJL-2/
# https://www.instagram.com/p/CUq25E1pWdW/
# https://www.instagram.com/p/CVOfUGEhYWB/
# https://www.instagram.com/p/CVExkV_J2B1/
# https://www.instagram.com/p/CVCFrecJgIb/
# https://www.instagram.com/p/CVUqrTlJssL/
# https://www.instagram.com/p/CVeIc7chS1i/
# https://www.instagram.com/p/CVkN2RMPOdm/
# https://www.instagram.com/p/CVkMX47BQw_/
# https://www.instagram.com/p/CVkKF0Lv5wo/
# https://www.instagram.com/p/CVkEuQoPD6o/
# https://www.instagram.com/p/CVkEtBvJrSY/
# https://www.instagram.com/p/CVkDlyDpRpe/
# https://www.instagram.com/p/CVkC7OfBOYO/
# https://www.instagram.com/p/CVkCYxrpEta/
# https://www.instagram.com/p/CVkAiRopKYf/
# https://www.instagram.com/p/CVkAJEtlIft/
# https://www.instagram.com/p/CVkAEfBvuHY/
# https://www.instagram.com/p/CVj_sF0pK1P/
# https://www.instagram.com/p/CVj_jw_J8PA/
# https://www.instagram.com/p/CVj_dvLpeaq/
# https://www.instagram.com/p/CVj-4lZpZXI/
# https://www.instagram.com/p/CVj98u0PudE/
# https://www.instagram.com/p/CVj8RwtJ1yO/
# https://www.instagram.com/p/CVj8Jybpp2D/
# https://www.instagram.com/p/CVj62uFhdB0/
# https://www.instagram.com/p/CVj12EMFds8/
# https://www.instagram.com/p/CVjz4j7h7BG/
# https://www.instagram.com/p/CVjyEnoJb9x/
# https://www.instagram.com/p/CVjx-UOJr9r/
# https://www.instagram.com/p/CVjxkEWhez0/
# https://www.instagram.com/p/CVjxA55Pgms/
# https://www.instagram.com/p/CVjwRP2hEft/
# https://www.instagram.com/p/CVjubxRPsmy/
# https://www.instagram.com/p/CVjtwNmhLmd/
# https://www.instagram.com/p/CVjtuaDPPZp/
# https://www.instagram.com/p/CVjszNDJBIx/
# https://www.instagram.com/p/CVjszNcJ6--/
# https://www.instagram.com/p/CVjst29vCn1/
# https://www.instagram.com/p/CVjrIq0BEbn/
# https://www.instagram.com/p/CVjqWDJvY4U/
# https://www.instagram.com/p/CVjpK60vYVg/
# https://www.instagram.com/p/CVjooDQjzn0/
# https://www.instagram.com/p/CVc17ArJwjO/
# https://www.instagram.com/p/CVedVyYplZ8/
# https://www.instagram.com/p/CVJ6h0KJL-2/
# https://www.instagram.com/p/CUq25E1pWdW/
# https://www.instagram.com/p/CVOfUGEhYWB/
# https://www.instagram.com/p/CVExkV_J2B1/
# https://www.instagram.com/p/CVCFrecJgIb/
# https://www.instagram.com/p/CVUqrTlJssL/
# https://www.instagram.com/p/CVeIc7chS1i/
# https://www.instagram.com/p/CVkC7OfBOYO/
# https://www.instagram.com/p/CVkCYxrpEta/
# https://www.instagram.com/p/CVkAiRopKYf/
# https://www.instagram.com/p/CVkAJEtlIft/
# https://www.instagram.com/p/CVkAEfBvuHY/
# https://www.instagram.com/p/CVj_sF0pK1P/
# https://www.instagram.com/p/CVj_jw_J8PA/
# https://www.instagram.com/p/CVj_dvLpeaq/
# https://www.instagram.com/p/CVj-4lZpZXI/
# https://www.instagram.com/p/CVj98u0PudE/
# https://www.instagram.com/p/CVj8RwtJ1yO/
# https://www.instagram.com/p/CVj8Jybpp2D/
# https://www.instagram.com/p/CVj62uFhdB0/
# https://www.instagram.com/p/CVj12EMFds8/
# https://www.instagram.com/p/CVjz4j7h7BG/
# https://www.instagram.com/p/CVjyEnoJb9x/
# https://www.instagram.com/p/CVjx-UOJr9r/
# https://www.instagram.com/p/CVjxkEWhez0/
# https://www.instagram.com/p/CVjxA55Pgms/
# https://www.instagram.com/p/CVjwRP2hEft/
# https://www.instagram.com/p/CVjubxRPsmy/
# https://www.instagram.com/p/CVjtwNmhLmd/
# https://www.instagram.com/p/CVjtuaDPPZp/
# https://www.instagram.com/p/CVjszNDJBIx/
# https://www.instagram.com/p/CVjszNcJ6--/
# https://www.instagram.com/p/CVjst29vCn1/
# https://www.instagram.com/p/CVjrIq0BEbn/
# https://www.instagram.com/p/CVjqWDJvY4U/
# https://www.instagram.com/p/CVjpK60vYVg/
# https://www.instagram.com/p/CVjooDQjzn0/
# https://www.instagram.com/p/CVjn5SpvUfb/
# https://www.instagram.com/p/CVjnbFbv4H7/
# https://www.instagram.com/p/CVjmxrOPpj3/
# https://www.instagram.com/p/CVjmbbPBiDd/
# https://www.instagram.com/p/CVjliCuvqXL/
# https://www.instagram.com/p/CVjkvDDvnhr/
# https://www.instagram.com/p/CVjid2zpnMb/
# https://www.instagram.com/p/CVjhDp2hM_K/
# https://www.instagram.com/p/CVjbkt4vFFz/
# https://www.instagram.com/p/CVjZs6QB6vJ/
# https://www.instagram.com/p/CVjYTO3hi3x/
# https://www.instagram.com/p/CVjXTcIv9P6/
# https://www.instagram.com/p/CVc17ArJwjO/
# https://www.instagram.com/p/CVedVyYplZ8/
# https://www.instagram.com/p/CVJ6h0KJL-2/
# https://www.instagram.com/p/CUq25E1pWdW/
# https://www.instagram.com/p/CVOfUGEhYWB/
# https://www.instagram.com/p/CVExkV_J2B1/
# https://www.instagram.com/p/CVCFrecJgIb/
# https://www.instagram.com/p/CVUqrTlJssL/
# https://www.instagram.com/p/CVeIc7chS1i/
# https://www.instagram.com/p/CVj62uFhdB0/
# https://www.instagram.com/p/CVj12EMFds8/
# https://www.instagram.com/p/CVjz4j7h7BG/
# https://www.instagram.com/p/CVjyEnoJb9x/
# https://www.instagram.com/p/CVjx-UOJr9r/
# https://www.instagram.com/p/CVjxkEWhez0/
# https://www.instagram.com/p/CVjxA55Pgms/
# https://www.instagram.com/p/CVjwRP2hEft/
# https://www.instagram.com/p/CVjubxRPsmy/
# https://www.instagram.com/p/CVjtwNmhLmd/
# https://www.instagram.com/p/CVjtuaDPPZp/
# https://www.instagram.com/p/CVjszNDJBIx/
# https://www.instagram.com/p/CVjszNcJ6--/
# https://www.instagram.com/p/CVjst29vCn1/
# https://www.instagram.com/p/CVjrIq0BEbn/
# https://www.instagram.com/p/CVjqWDJvY4U/
# https://www.instagram.com/p/CVjpK60vYVg/
# https://www.instagram.com/p/CVjooDQjzn0/
# https://www.instagram.com/p/CVjn5SpvUfb/
# https://www.instagram.com/p/CVjnbFbv4H7/
# https://www.instagram.com/p/CVjmxrOPpj3/
# https://www.instagram.com/p/CVjmbbPBiDd/
# https://www.instagram.com/p/CVjliCuvqXL/
# https://www.instagram.com/p/CVjkvDDvnhr/
# https://www.instagram.com/p/CVjid2zpnMb/
# https://www.instagram.com/p/CVjhDp2hM_K/
# https://www.instagram.com/p/CVjbkt4vFFz/
# https://www.instagram.com/p/CVjZs6QB6vJ/
# https://www.instagram.com/p/CVjYTO3hi3x/
# https://www.instagram.com/p/CVjXTcIv9P6/
# https://www.instagram.com/p/CVjTV5AB5v6/
# https://www.instagram.com/p/CVjOnPcPMPl/
# https://www.instagram.com/p/CVjNulHBgdG/
# https://www.instagram.com/p/CVjNksLPklG/
# https://www.instagram.com/p/CVjLi4thohy/
# https://www.instagram.com/p/CVjKFQTPYnh/
# https://www.instagram.com/p/CVjJv2wv0Fw/
# https://www.instagram.com/p/CVjIr_svdON/
# https://www.instagram.com/p/CVjIUoIhBmE/
# https://www.instagram.com/p/CVi9iJzh6n4/
# https://www.instagram.com/p/CVirDQahr0D/
# https://www.instagram.com/p/CVif-gRPg4F/
